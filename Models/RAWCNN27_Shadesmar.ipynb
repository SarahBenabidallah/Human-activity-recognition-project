# %%
import pandas as pd
import keras
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Dense,  Activation, Conv2D, MaxPool2D,ConvLSTM2D, MaxPooling2D,LSTM,Conv1D,MaxPool1D,GlobalAveragePooling1D,TimeDistributed,MaxPooling1D
from keras.layers import Flatten, Dropout, BatchNormalization, Reshape
from keras.utils.vis_utils import plot_model

import os
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
#from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
signals = pd.read_csv("signals.csv")
metadata = pd.read_csv("metadata.csv")
signals_test = pd.read_csv("signals_test.csv")
metadata_test = pd.read_csv("metadata_test.csv")
signals.shape
# Out:
# (811637, 5)

# %%
m = metadata[metadata['x-axis__length']!=100]
m_test = metadata_test[metadata_test['x-axis__length']!=100].copy()
m_test
signals = signals[~signals.user_snippet.isin(m['user_snippet'].values)]
signals.shape
# Out:
# (810100, 5)

# %%
merged = pd.merge(signals, metadata[['user_snippet', 'activity']], on='user_snippet')
merged.head(10)
# Out:
#   user_snippet  x-axis  y-axis  z-axis  timestamp  activity
# 0       1008_0   -5.01   10.99    4.75        0.0  Upstairs
# 1       1008_0   -2.72   13.25    4.44       50.0  Upstairs
# 2       1008_0    5.41   13.18    1.27      100.0  Upstairs
# 3       1008_0   -1.80    0.15   -2.72      150.0  Upstairs
# 4       1008_0   -2.91   -3.87   -2.49      200.0  Upstairs
# 5       1008_0   -3.87   -0.91    1.80      250.0  Upstairs
# 6       1008_0   -3.64   -2.22    2.83      300.0  Upstairs
# 7       1008_0   -9.11   -0.84   10.95      350.0  Upstairs
# 8       1008_0  -14.06    3.60   13.44      400.0  Upstairs
# 9       1008_0  -10.46    3.64    5.79      450.0  Upstairs

# %%
merged.shape
# Out:
# (810100, 6)

# %%
def clean_data(dataframe):
    """ Removes the columns "SubjectID" and "Timestamp" from the dataframe """

    cleaned_df = dataframe.drop(["timestamp"], axis = 1).copy()

    return cleaned_df

# %%
def scale_data(data):
    """ Normalizes the data using StandardScaler() function """
    
    le = LabelEncoder()
    data['ActivityCode'] = le.fit_transform(data['activity'])
    
    X = data[['x-axis', 'y-axis', 'z-axis']]
    y = data['ActivityCode']
    
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    
    scaled_df = pd.DataFrame(data = X, columns = ['x-axis', 'y-axiz', 'z-axis'])
    scaled_df['user_snippet'] = data['user_snippet']
    scaled_df['ActivityCode'] = y.values
    
    return scaled_df, le, scaler

# %%
def preprocess_data(dataframe):    
    """ Preprocesses the data using clean() and scale() functions """

    cleaned_df = clean_data(dataframe)
    
    return scale_data(cleaned_df)

# %%
def plot_learningCurve(history, epochs):
    """ Plots training & validation accuracy values """

    epoch_range = range(1, epochs+1)
    plt.plot(epoch_range, history.history['accuracy'])
    plt.plot(epoch_range, history.history["val_accuracy"])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='lower right')
    plt.show()
    
    """ Plots training & validation loss values """
    
    plt.plot(epoch_range, history.history['loss'])
    plt.plot(epoch_range, history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper right')
    plt.show()

# %%
import scipy.stats as stats
def get_frames(df):
    n_features = 3
    frames = []
    labels = []
    #users = df['user_snippet'].unique()
    for i in range(0, len(df) - 100, 100):
        
       
        
        z = df['z-axis'].values[i: i + 100]
        x = df['x-axis'].values[i: i + 100]
        y = df['y-axiz'].values[i: i + 100]
        
        
        label = stats.mode(df['ActivityCode'][i: i + 100])[0][0]
        frames.append([x, y, z])
        labels.append(label)

    frames = np.asarray(frames).reshape(-1, 100, n_features)
    labels = np.asarray(labels)

    return frames, labels

# %%
def get_model(inputs):
    """ Builds the model (the Convolutional Neural Network) """
    
    # Defines model
    model = Sequential()
    model.add(Conv2D(64, (2, 2), activation = 'relu', input_shape = inputs[0].shape))
    model.add(Conv2D(64, (2, 2), activation = 'relu', input_shape = inputs[0].shape))
    model.add(Conv2D(64, (2, 2), activation = 'relu', input_shape = inputs[0].shape))
    model.add(Conv2D(64, (2, 2), activation = 'relu', input_shape = inputs[0].shape))



#     model.add(Dropout(0.1))
#     model.add(Conv2D(64, (2, 2), activation='relu'))
#     model.add(Dropout(0.2))
    model.add(MaxPooling2D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(256, activation = 'relu'))
    model.add(Dense(128, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(6, activation='softmax'))

    # Compiles model
    model.compile(optimizer=Adam(learning_rate = 0.0001), 
                  loss = 'sparse_categorical_crossentropy', 
                  metrics = ['accuracy'])
    
    return model
def get_model2(input):
    input_shape = input_shape.shape
    model = Sequential()
    model.add(LSTM(32, return_sequences=True, input_shape=(input_shape,1), activation='relu'))
    model.add(LSTM(32,return_sequences=True, activation='relu'))
    model.add(Reshape((1, 240, 32)))
    model.add(Conv1D(filters=64,kernel_size=2, activation='relu', strides=2))
    model.add(Reshape((120, 64)))
    model.add(MaxPool1D(pool_size=4, padding='same'))
    model.add(Conv1D(filters=192, kernel_size=2, activation='relu', strides=1))
    model.add(Reshape((29, 192)))
    model.add(GlobalAveragePooling1D())
    model.add(BatchNormalization(epsilon=1e-06))
    model.add(Dense(6))
    model.add(Activation('softmax'))
    print(model.summary())
    return model

# %%
process_data,le,scaler = preprocess_data(merged)
process_data.shape
# Out:
# (810100, 5)

# %%
X, y = get_frames(process_data)

# %%
X.shape
# Out:
# (8100, 100, 3)

# %%
time_period, sensors = X.shape[1], X.shape[2]

# %%
input_shape = time_period * sensors
x_train = X.reshape(X.shape[0], input_shape)
print("Input Shape: ", input_shape)
print("Input Data Shape: ", X.shape)
# Out:
# Input Shape:  300
# Input Data Shape:  (8100, 100, 3)

# %%
x_train = X.astype('float32')
y_train = y.astype('float32')

# %%
from tensorflow.keras.utils import to_categorical
y_train_hot = to_categorical(y_train, 6)
print("y_train shape: ", y_train_hot.shape)
# Out:
# y_train shape:  (8100, 6)

# %%
# reset tensorflow session
from tensorflow.keras import backend as K
K.clear_session()

# %%
from keras.regularizers import L1L2

model = Sequential()
model.add(TimeDistributed(Conv1D(filters=80, kernel_size=5, activation='relu'), input_shape=(1,100,3)))
model.add(TimeDistributed(Conv1D(filters=80, kernel_size=5, activation='relu')))
model.add(TimeDistributed(Dropout(0.6)))
model.add(TimeDistributed(MaxPooling1D(pool_size=3)))
model.add(TimeDistributed(Conv1D(filters=128, kernel_size=5, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(pool_size=3)))
model.add(TimeDistributed(Dropout(0.6)))
model.add(TimeDistributed(Flatten()))
model.add(LSTM(128))
model.add(Dropout(0.6))
model.add(Dense(100, activation='relu'))
model.add(Dense(6, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='RMSprop', metrics=['accuracy'])

#units before 64 and adam optimiser
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 1, 96, 80)        1280
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 1, 92, 80)        32080
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 1, 92, 80)        0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 1, 30, 80)        0
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 1, 26, 128)       51328
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 1, 8, 128)        0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 1, 8, 128)        0
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 1, 1024)          0
#  tributed)
#
#  lstm (LSTM)                 (None, 128)               590336
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 100)               12900
#
#  dense_1 (Dense)             (None, 6)                 606
#
# =================================================================
# Total params: 688,530
# Trainable params: 688,530
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
x_train = x_train.reshape((x_train.shape[0], 1,100,3))
x_train.shape
# Out:
# (8100, 1, 100, 3)

# %%
#x_train = x_train.reshape(-1,100,3)

callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath='best_model.{epoch:02d}-{val_loss:.2f}.h5',
        monitor='val_loss', save_best_only=True),
    keras.callbacks.EarlyStopping(monitor='accuracy', patience=1)
]
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x_train,
                    y_train_hot,
                    batch_size= 128, 
                    validation_split=0.2,
                    epochs=50
                   )
# Out:
# Epoch 1/50
# 51/51 [==============================] - 28s 355ms/step - loss: 1.0043 - accuracy: 0.6289 - val_loss: 0.5411 - val_accuracy: 0.8414
# Epoch 2/50
# 51/51 [==============================] - 18s 358ms/step - loss: 0.6597 - accuracy: 0.7742 - val_loss: 0.4467 - val_accuracy: 0.8426
# Epoch 3/50
# 51/51 [==============================] - 17s 333ms/step - loss: 0.5403 - accuracy: 0.8019 - val_loss: 0.4107 - val_accuracy: 0.8519
# Epoch 4/50
# 51/51 [==============================] - 16s 321ms/step - loss: 0.4962 - accuracy: 0.8162 - val_loss: 0.4356 - val_accuracy: 0.8469
# Epoch 5/50
# 51/51 [==============================] - 17s 328ms/step - loss: 0.4341 - accuracy: 0.8390 - val_loss: 0.4618 - val_accuracy: 0.8401
# Epoch 6/50
# 51/51 [==============================] - 17s 337ms/step - loss: 0.3954 - accuracy: 0.8573 - val_loss: 0.3680 - val_accuracy: 0.8704
# Epoch 7/50
# 51/51 [==============================] - 16s 310ms/step - loss: 0.3582 - accuracy: 0.8685 - val_loss: 0.3848 - val_accuracy: 0.8543
# Epoch 8/50
# 51/51 [==============================] - 16s 323ms/step - loss: 0.3087 - accuracy: 0.8861 - val_loss: 0.3107 - val_accuracy: 0.9006
# Epoch 9/50
# 51/51 [==============================] - 16s 319ms/step - loss: 0.2979 - accuracy: 0.8951 - val_loss: 0.3142 - val_accuracy: 0.8870
# Epoch 10/50
# 51/51 [==============================] - 17s 327ms/step - loss: 0.2532 - accuracy: 0.9094 - val_loss: 0.2531 - val_accuracy: 0.9265
# Epoch 11/50
# 51/51 [==============================] - 16s 316ms/step - loss: 0.2493 - accuracy: 0.9116 - val_loss: 0.3239 - val_accuracy: 0.8932
# Epoch 12/50
# 51/51 [==============================] - 16s 323ms/step - loss: 0.2268 - accuracy: 0.9204 - val_loss: 0.2533 - val_accuracy: 0.9062
# Epoch 13/50
# 51/51 [==============================] - 17s 330ms/step - loss: 0.2139 - accuracy: 0.9262 - val_loss: 0.2496 - val_accuracy: 0.9086
# Epoch 14/50
# 51/51 [==============================] - 19s 365ms/step - loss: 0.2006 - accuracy: 0.9309 - val_loss: 0.3030 - val_accuracy: 0.8728
# Epoch 15/50
# 51/51 [==============================] - 18s 349ms/step - loss: 0.1864 - accuracy: 0.9327 - val_loss: 0.4897 - val_accuracy: 0.8031
# Epoch 16/50
# 51/51 [==============================] - 17s 331ms/step - loss: 0.1771 - accuracy: 0.9366 - val_loss: 0.2698 - val_accuracy: 0.8796
# Epoch 17/50
# 51/51 [==============================] - 15s 297ms/step - loss: 0.1684 - accuracy: 0.9423 - val_loss: 0.2779 - val_accuracy: 0.8870
# Epoch 18/50
# 51/51 [==============================] - 17s 326ms/step - loss: 0.1646 - accuracy: 0.9432 - val_loss: 0.6382 - val_accuracy: 0.7889
# Epoch 19/50
# 51/51 [==============================] - 16s 315ms/step - loss: 0.1525 - accuracy: 0.9505 - val_loss: 0.3346 - val_accuracy: 0.8673
# Epoch 20/50
# 51/51 [==============================] - 17s 342ms/step - loss: 0.1476 - accuracy: 0.9506 - val_loss: 0.3342 - val_accuracy: 0.8593
# Epoch 21/50
# 51/51 [==============================] - 16s 307ms/step - loss: 0.1393 - accuracy: 0.9545 - val_loss: 0.3279 - val_accuracy: 0.8580
# Epoch 22/50
# 51/51 [==============================] - 16s 307ms/step - loss: 0.1347 - accuracy: 0.9542 - val_loss: 0.3778 - val_accuracy: 0.8506
# Epoch 23/50
# 51/51 [==============================] - 16s 318ms/step - loss: 0.1279 - accuracy: 0.9560 - val_loss: 0.1948 - val_accuracy: 0.9296
# Epoch 24/50
# 51/51 [==============================] - 17s 339ms/step - loss: 0.1278 - accuracy: 0.9573 - val_loss: 0.3644 - val_accuracy: 0.8525
# Epoch 25/50
# 51/51 [==============================] - 17s 325ms/step - loss: 0.1157 - accuracy: 0.9623 - val_loss: 0.3217 - val_accuracy: 0.8796
# Epoch 26/50
# 51/51 [==============================] - 17s 328ms/step - loss: 0.1108 - accuracy: 0.9622 - val_loss: 0.3010 - val_accuracy: 0.8790
# Epoch 27/50
# 51/51 [==============================] - 17s 334ms/step - loss: 0.1055 - accuracy: 0.9654 - val_loss: 0.3427 - val_accuracy: 0.8858
# Epoch 28/50
# 51/51 [==============================] - 20s 385ms/step - loss: 0.1018 - accuracy: 0.9670 - val_loss: 0.2633 - val_accuracy: 0.8969
# Epoch 29/50
# 51/51 [==============================] - 19s 367ms/step - loss: 0.1075 - accuracy: 0.9634 - val_loss: 0.2595 - val_accuracy: 0.8926
# Epoch 30/50
# 51/51 [==============================] - 17s 340ms/step - loss: 0.1061 - accuracy: 0.9670 - val_loss: 0.3011 - val_accuracy: 0.8790
# Epoch 31/50
# 51/51 [==============================] - 16s 323ms/step - loss: 0.1006 - accuracy: 0.9667 - val_loss: 0.3181 - val_accuracy: 0.8815
# Epoch 32/50
# 51/51 [==============================] - 16s 322ms/step - loss: 0.0919 - accuracy: 0.9676 - val_loss: 0.2000 - val_accuracy: 0.9315
# Epoch 33/50
# 51/51 [==============================] - 20s 390ms/step - loss: 0.0905 - accuracy: 0.9693 - val_loss: 0.2900 - val_accuracy: 0.8877
# Epoch 34/50
# 51/51 [==============================] - 18s 361ms/step - loss: 0.0937 - accuracy: 0.9705 - val_loss: 0.3688 - val_accuracy: 0.8673
# Epoch 35/50
# 51/51 [==============================] - 17s 334ms/step - loss: 0.0939 - accuracy: 0.9710 - val_loss: 0.2134 - val_accuracy: 0.9204
# Epoch 36/50
# 51/51 [==============================] - 17s 342ms/step - loss: 0.0902 - accuracy: 0.9696 - val_loss: 0.2690 - val_accuracy: 0.9037
# Epoch 37/50
# 51/51 [==============================] - 18s 344ms/step - loss: 0.0765 - accuracy: 0.9739 - val_loss: 0.2309 - val_accuracy: 0.9191
# Epoch 38/50
# 51/51 [==============================] - 17s 325ms/step - loss: 0.0817 - accuracy: 0.9748 - val_loss: 0.2030 - val_accuracy: 0.9265
# Epoch 39/50
# 51/51 [==============================] - 18s 351ms/step - loss: 0.0753 - accuracy: 0.9752 - val_loss: 0.3796 - val_accuracy: 0.8753
# Epoch 40/50
# 51/51 [==============================] - 17s 338ms/step - loss: 0.0780 - accuracy: 0.9752 - val_loss: 0.3114 - val_accuracy: 0.8877
# Epoch 41/50
# 51/51 [==============================] - 16s 323ms/step - loss: 0.0728 - accuracy: 0.9761 - val_loss: 0.1950 - val_accuracy: 0.9309
# Epoch 42/50
# 51/51 [==============================] - 17s 326ms/step - loss: 0.0783 - accuracy: 0.9745 - val_loss: 0.3220 - val_accuracy: 0.8926
# Epoch 43/50
# 51/51 [==============================] - 17s 325ms/step - loss: 0.0670 - accuracy: 0.9796 - val_loss: 0.3201 - val_accuracy: 0.8895
# Epoch 44/50
# 51/51 [==============================] - 18s 356ms/step - loss: 0.0743 - accuracy: 0.9778 - val_loss: 0.4690 - val_accuracy: 0.8685
# Epoch 45/50
# 51/51 [==============================] - 17s 337ms/step - loss: 0.0672 - accuracy: 0.9792 - val_loss: 0.2927 - val_accuracy: 0.9019
# Epoch 46/50
# 51/51 [==============================] - 18s 350ms/step - loss: 0.0764 - accuracy: 0.9741 - val_loss: 0.2550 - val_accuracy: 0.9130
# Epoch 47/50
# 51/51 [==============================] - 18s 344ms/step - loss: 0.0652 - accuracy: 0.9785 - val_loss: 0.2146 - val_accuracy: 0.9302
# Epoch 48/50
# 51/51 [==============================] - 19s 369ms/step - loss: 0.0657 - accuracy: 0.9784 - val_loss: 0.3840 - val_accuracy: 0.8704
# Epoch 49/50
# 51/51 [==============================] - 17s 330ms/step - loss: 0.0582 - accuracy: 0.9818 - val_loss: 0.2520 - val_accuracy: 0.9111
# Epoch 50/50
# 51/51 [==============================] - 18s 351ms/step - loss: 0.0681 - accuracy: 0.9790 - val_loss: 0.2972 - val_accuracy: 0.9080

# %%
def plot_history(history):
    plt.figure()
    plt.subplot(2,1,1)
    plt.plot(history.history['loss'])
    
    plt.plot(history.history['val_loss'])
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'])
    plt.subplot(2,1,2)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'])
    return;

plot_history(history)

# %%
m_test = metadata_test[metadata_test['x-axis__length']!=100].copy()
signals_new = signals_test[~signals_test.user_snippet.isin(m_test['user_snippet'].values)]
signals_new.shape
# Out:
# (261300, 5)

# %%
X = signals_new[['x-axis', 'y-axis', 'z-axis']]

X = scaler.transform(X)

scaled_df = pd.DataFrame(data = X, columns = ['x-axis', 'y-axiz', 'z-axis'])
scaled_df['user_snippet'] = signals_new['user_snippet']

# %%
n_features = 3
frames = []

#users = df['user_snippet'].unique()
for i in range(0, len(scaled_df), 100):
    
    
    
    z = scaled_df['z-axis'].values[i: i + 100]
    x = scaled_df['x-axis'].values[i: i + 100]
    y = scaled_df['y-axiz'].values[i: i + 100]
    
    
    
    frames.append([x, y, z])

frames = np.asarray(frames).reshape(-1, 100, n_features)

# %%
frames = frames.reshape(-1,1, 100,3)
y_pred = model.predict(frames, verbose=0)
classes_x=np.argmax(y_pred,axis=1)
len(classes_x)
# Out:
# 2613

# %%
predictions = le.inverse_transform(classes_x)

# %%
final = metadata_test[metadata_test['x-axis__length']==100.0].copy()
final['prediction'] = predictions

# %%
pred = pd.DataFrame(data = final, columns = ['user_snippet', 'prediction'])

# %%
ensemble = pd.read_csv('ensemble7.csv')

# %%
others = ensemble[~ensemble.user_snippet.isin(pred['user_snippet'].values)]
others
# Out:
#      user_snippet  prediction
# 320      2066_320  Downstairs
# 563      2069_202    Standing
# 820      2178_137  Downstairs
# 954       2203_50    Upstairs
# 1415     2235_129     Sitting
# 1868     2346_139    Standing
# 2105     2383_152    Standing
# 2554     2480_267  Downstairs

# %%
c = pd.concat([pred,others])
c.shape
# Out:
# (2621, 2)

# %%
check = pd.merge(ensemble, c, on='user_snippet')
check
# Out:
#      user_snippet prediction_x prediction_y
# 0          2066_0     Upstairs     Upstairs
# 1          2066_1      Walking      Walking
# 2          2066_2      Jogging      Jogging
# 3          2066_3      Walking      Walking
# 4          2066_4      Walking      Walking
# ...           ...          ...          ...
# 2616     2480_329      Walking      Walking
# 2617     2480_330      Walking      Walking
# 2618     2480_331   Downstairs      Walking
# 2619     2480_332      Sitting      Sitting
# 2620     2480_333      Jogging      Jogging
#
# [2621 rows x 3 columns]

# %%
confusion_matrix(check['prediction_x'],check['prediction_y'])
# Out:
# array([[216,   1,   1,   0,   5,   9],
#        [ 24, 779,   0,   0,   5,   2],
#        [  0,   0,  91,   7,   3,   0],
#        [  0,   0,   0, 108,   0,   1],
#        [118,   1,   0,   2, 331,  14],
#        [  6,   0,   0,   0,   6, 891]], dtype=int64)

# %%
check['prediction'] = check['prediction_y']
check= check.drop(columns=['prediction_x','prediction_y'])

# %%
check.to_csv("submitRawCNN27V2.csv",index=False)

# %%
pred1 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/ensemble9.csv")
pred12 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/ensemble8.csv")
pred2 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/submitRawCNN23.csv")
pred6 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/ensemble7.csv")
pred7 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/ensemble6.csv")
pred15 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/ensemble5.csv")
pred15 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/submitSVMLP.csv")
pred16 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/submitRawCNN24.csv")
pred18 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/submitRawCNN26.csv")
pred19 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/ensemble14.csv")
pred20 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/ensemble12.csv")
pred21= pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/ensemble11.csv")
pred23 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/submitRawCNN22.csv")
pred24 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/submitRawCNN27.csv")
pred25 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/ensemble17.csv")
pred26 = pd.read_csv("c:/Users/sarah/OneDrive - Liverpool John Moores University/LJMU/ML/Project/SVM/submitRawCNN27V2.csv")

# %%
df = pd.DataFrame()
predictions = [pred1,pred2,pred6,pred7, pred12,pred15,pred16,pred18, pred19, pred20,pred21,pred23, pred24, pred25, pred26]
for i in range (0, len(predictions)):
    df[i] = predictions[i]['prediction']

# %%
final = df.mode(axis=1)
pred2['prediction'] = final[0]
pred2.to_csv("ensemble23.csv",index=False)
